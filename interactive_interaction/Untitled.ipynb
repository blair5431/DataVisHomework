# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
#####################The following code will allow you to inspect the DB to see what tables and columns are there using reflection
# Create the connection engine
engine = create_engine("sqlite:///DataSets/belly_button_biodiversity.sqlite")

# %%
# Create the inspector and connect it to the engine
### BEGIN SOLUTION
inspector = inspect(engine)
### END SOLUTION

# %%
# Collect the names of tables within the database
### BEGIN SOLUTION
inspector.get_table_names()
### END SOLUTION

# %%
# Using the inspector to print the column names within the 'Salaries' table and its types
### BEGIN SOLUTION
columns = inspector.get_columns('samples')
names = []
for column in columns:
    print(column["name"], column["type"])
    name = column["name"]
    names.append(name)
names.pop(0)

# %%
print(names)

# %%
PRAGMA table_info("samples");

# %%
columns = inspector.get_columns('otu')
names = []
for column in columns:
    print(column["name"], column["type"])
    name = column["name"]

# %%
columns = inspector.get_columns('samples_metadata')
names = []
for column in columns:
    print(column["name"], column["type"])
    name = column["name"]

# %%
# import necessary libraries
import pandas as pd

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

from flask import (
    Flask,
    render_template,
    jsonify)

#################################################
# Database Setup
#################################################
engine = create_engine("sqlite:///DataSets/belly_button_biodiversity.sqlite")

# reflect an existing database into a new model
# copies table strucutres from database structure as it already exixts
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

#print all the calsses mapped to the base
Base.classes.keys()

# Assign each class to is own variable
Otu=Base.classes.otu
Samples=Base.classes.samples
Samples_metabdata =Base.classes.samples_metadata

inspector = inspect(engine)

# Create our session (link) from Python to the DB
session = Session(engine)

# %%
merged_data = session.query(Samples_metabdata).filter(Samples.otu_id == Samples_metabdata.SAMPLEID).all()

# %%
merged_data
# Out:
# [<sqlalchemy.ext.automap.samples_metadata at 0x108a12eb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a12f28>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a12f98>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a0b8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a128>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a208>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a278>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a2e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a4e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a6d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a8d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1a978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1aa20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1aac8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1ab70>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1ac18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1acc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1ad68>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1ae10>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1aeb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a1af60>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a210f0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21240>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a212e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a214e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a216d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a218d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21a20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21ac8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21b70>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21c18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21cc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21d68>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21e10>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21eb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a21f60>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a270f0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27240>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a272e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a274e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a276d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a278d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27a20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27ac8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27b70>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27c18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27cc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27d68>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27e10>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27eb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a27f60>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e0f0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e240>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e2e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e4e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e6d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e8d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2e978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ea20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2eac8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2eb70>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ec18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ecc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ed68>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ee10>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2eeb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a2ef60>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a350f0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35240>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a352e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a354e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a356d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x10505e320>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050e8f28>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x103bf2048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f7cc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f74e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f7c50>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f72b0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f7cf8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f73c8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f7400>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x1050f7c18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a358d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35a20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35ac8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35b70>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35c18>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35cc0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35d68>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35e10>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35eb8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a35f60>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e048>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e0f0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e198>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e240>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e2e8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e390>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e438>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e4e0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e588>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e630>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e6d8>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e780>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e828>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e8d0>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3e978>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3ea20>,
#  <sqlalchemy.ext.automap.samples_metadata at 0x108a3eac8>]

# %%
temp_obs_df = pd.DataFrame(stations_join[:6045])
temp_obs_df
# Out:
#                                                      0
# 0    <sqlalchemy.ext.automap.samples_metadata objec...
# 1    <sqlalchemy.ext.automap.samples_metadata objec...
# 2    <sqlalchemy.ext.automap.samples_metadata objec...
# 3    <sqlalchemy.ext.automap.samples_metadata objec...
# 4    <sqlalchemy.ext.automap.samples_metadata objec...
# 5    <sqlalchemy.ext.automap.samples_metadata objec...
# 6    <sqlalchemy.ext.automap.samples_metadata objec...
# 7    <sqlalchemy.ext.automap.samples_metadata objec...
# 8    <sqlalchemy.ext.automap.samples_metadata objec...
# 9    <sqlalchemy.ext.automap.samples_metadata objec...
# 10   <sqlalchemy.ext.automap.samples_metadata objec...
# 11   <sqlalchemy.ext.automap.samples_metadata objec...
# 12   <sqlalchemy.ext.automap.samples_metadata objec...
# 13   <sqlalchemy.ext.automap.samples_metadata objec...
# 14   <sqlalchemy.ext.automap.samples_metadata objec...
# 15   <sqlalchemy.ext.automap.samples_metadata objec...
# 16   <sqlalchemy.ext.automap.samples_metadata objec...
# 17   <sqlalchemy.ext.automap.samples_metadata objec...
# 18   <sqlalchemy.ext.automap.samples_metadata objec...
# 19   <sqlalchemy.ext.automap.samples_metadata objec...
# 20   <sqlalchemy.ext.automap.samples_metadata objec...
# 21   <sqlalchemy.ext.automap.samples_metadata objec...
# 22   <sqlalchemy.ext.automap.samples_metadata objec...
# 23   <sqlalchemy.ext.automap.samples_metadata objec...
# 24   <sqlalchemy.ext.automap.samples_metadata objec...
# 25   <sqlalchemy.ext.automap.samples_metadata objec...
# 26   <sqlalchemy.ext.automap.samples_metadata objec...
# 27   <sqlalchemy.ext.automap.samples_metadata objec...
# 28   <sqlalchemy.ext.automap.samples_metadata objec...
# 29   <sqlalchemy.ext.automap.samples_metadata objec...
# ..                                                 ...
# 123  <sqlalchemy.ext.automap.samples_metadata objec...
# 124  <sqlalchemy.ext.automap.samples_metadata objec...
# 125  <sqlalchemy.ext.automap.samples_metadata objec...
# 126  <sqlalchemy.ext.automap.samples_metadata objec...
# 127  <sqlalchemy.ext.automap.samples_metadata objec...
# 128  <sqlalchemy.ext.automap.samples_metadata objec...
# 129  <sqlalchemy.ext.automap.samples_metadata objec...
# 130  <sqlalchemy.ext.automap.samples_metadata objec...
# 131  <sqlalchemy.ext.automap.samples_metadata objec...
# 132  <sqlalchemy.ext.automap.samples_metadata objec...
# 133  <sqlalchemy.ext.automap.samples_metadata objec...
# 134  <sqlalchemy.ext.automap.samples_metadata objec...
# 135  <sqlalchemy.ext.automap.samples_metadata objec...
# 136  <sqlalchemy.ext.automap.samples_metadata objec...
# 137  <sqlalchemy.ext.automap.samples_metadata objec...
# 138  <sqlalchemy.ext.automap.samples_metadata objec...
# 139  <sqlalchemy.ext.automap.samples_metadata objec...
# 140  <sqlalchemy.ext.automap.samples_metadata objec...
# 141  <sqlalchemy.ext.automap.samples_metadata objec...
# 142  <sqlalchemy.ext.automap.samples_metadata objec...
# 143  <sqlalchemy.ext.automap.samples_metadata objec...
# 144  <sqlalchemy.ext.automap.samples_metadata objec...
# 145  <sqlalchemy.ext.automap.samples_metadata objec...
# 146  <sqlalchemy.ext.automap.samples_metadata objec...
# 147  <sqlalchemy.ext.automap.samples_metadata objec...
# 148  <sqlalchemy.ext.automap.samples_metadata objec...
# 149  <sqlalchemy.ext.automap.samples_metadata objec...
# 150  <sqlalchemy.ext.automap.samples_metadata objec...
# 151  <sqlalchemy.ext.automap.samples_metadata objec...
# 152  <sqlalchemy.ext.automap.samples_metadata objec...
#
# [153 rows x 1 columns]

# %%
test="BB_904"

# %%
cut = test.replace("BB_", "")

# %%
cut
# Out:
# '904'
